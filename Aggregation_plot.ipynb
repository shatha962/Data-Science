# %% [markdown]
# <a href="https://colab.research.google.com/github/shatha962/Data-Science/blob/main/Aggregation_plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns',100)

# %%
fname = "/content/drive/MyDrive/AXSOSACADEMY/01-Fundamentals/Week02/Data/ames-housing-cleaned-eda.csv"
df = pd.read_csv(fname)
df = df.set_index("PID")
df.head()
# Out:
#           MS Zoning  Lot Frontage  Lot Area Street    Alley Utilities  \
# PID
# 907227090        RL            60      7200   Pave  MISSING    AllPub
# 527108010        RL           134     19378   Pave  MISSING    AllPub
# 534275170        RL            -1     12772   Pave  MISSING    AllPub
# 528104050        RL           114     14803   Pave  MISSING    AllPub
# 533206070        FV            32      3784   Pave     Pave    AllPub
#
#           Neighborhood Bldg Type House Style  Overall Qual  Overall Cond  \
# PID
# 907227090      CollgCr      1Fam      1Story             5             8
# 527108010      Gilbert      1Fam      2Story             7             5
# 534275170        NAmes      1Fam      1Story             6             8
# 528104050      NridgHt      1Fam      1Story            10             5
# 533206070      Somerst    TwnhsE      1Story             8             5
#
#            Year Built  Year Remodeled Exter Qual Exter Cond  Bsmt Unf Sqft  \
# PID
# 907227090        1972            1972         TA         TA          427.0
# 527108010        2005            2006         Gd         TA         1335.0
# 534275170        1960            1998         TA         Gd          460.0
# 528104050        2007            2008         Ex         TA          442.0
# 533206070        2006            2007         Gd         TA         1451.0
#
#            Total Bsmnt Sqft Central Air  Living Area Sqft  Bedroom  Kitchen  \
# PID
# 907227090             864.0           Y             864.0        3        1
# 527108010            1392.0           Y            2462.0        4        1
# 534275170             958.0           Y             958.0        2        1
# 528104050            2078.0           Y            2084.0        2        1
# 533206070            1511.0           Y            1565.0        2        1
#
#            Total Rooms Garage Type  Garage Yr Blt  Garage Cars  Garage Area  \
# PID
# 907227090            5      Detchd         1977.0          1.0        297.0
# 527108010            9      Attchd         2006.0          2.0        576.0
# 534275170            5      Attchd         1960.0          1.0        301.0
# 528104050            7      Attchd         2007.0          3.0       1220.0
# 533206070            5      Attchd         2006.0          2.0        476.0
#
#           Garage Qual Garage Cond Paved Drive    Fence  SalePrice  Month  \
# PID
# 907227090          TA          TA           Y    MnPrv   119900.0      3
# 527108010          TA          TA           Y  MISSING   320000.0      3
# 534275170          TA          TA           Y  MISSING   151500.0      4
# 528104050          TA          TA           Y  MISSING   385000.0      6
# 533206070          TA          TA           Y  MISSING   193800.0      2
#
#            Year  Total Full Baths  Total Half Baths
# PID
# 907227090  2006               1.0               0.0
# 527108010  2006               3.0               1.0
# 534275170  2007               1.0               0.0
# 528104050  2008               3.0               0.0
# 533206070  2007               3.0               0.0

# %%
# We can make a scatter plot with pandas' .plot.
ax = df.plot(kind='scatter', x='Living Area Sqft', y='SalePrice')

# %%
# Scatter Plot with Matplotlib
fig, ax = plt.subplots()
ax.scatter(df['Living Area Sqft'], df['SalePrice']);
ax.set(xlabel='Living Area Sqft', ylabel="SalePrice");

# %%
ax = sns.scatterplot(data=df, x='Living Area Sqft', y='SalePrice');

# %%
# sns.regplot requires the same arguments as scatterplot
ax = sns.regplot(data=df, x='Living Area Sqft', y='SalePrice');

# %%
# Saving the arguments for the line color in a dict to to use as line_kws
line_kws = dict(color='black')
ax = sns.regplot(data=df, x='Living Area Sqft', y='SalePrice', line_kws=line_kws);

# %%
# Saving the arguments for the markers' edge color in a dict to to use as scatter_kws
scatter_kws = dict(edgecolor='white')
ax = sns.regplot(data=df, x="Living Area Sqft", y="SalePrice",
                 line_kws=line_kws, scatter_kws=scatter_kws);

# %%
# Creating a scatterplot using Central Air as the hue argument
ax = sns.scatterplot(data=df, x="Living Area Sqft" , y="SalePrice",
                     hue="Central Air");

# %%
# Use sns.lmplot and save as g
g = sns.lmplot(data=df, x="Living Area Sqft", y="SalePrice",
                scatter_kws=scatter_kws,hue="Central Air");

# %%
# what is the output of the lmplot
type(g)
# Out:
# seaborn.axisgrid.FacetGrid

# %%
# Set the title using g.ax.set_title()
g = sns.lmplot(data=df, x="Living Area Sqft", y="SalePrice",
               scatter_kws=scatter_kws,
                hue="Central Air");
g.ax.set_title("LM Plot");
